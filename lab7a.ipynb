# %%
import torch
import cv2

# Model
model = torch.hub.load('ultralytics/yolov5', 'yolov5n', pretrained=True)

imgs = ['https://ultralytics.com/images/zidane.jpg']  # batch of images

# Inference


# Results
results.print()
results.show()  # or .save() to runs/results/

results.xyxy[0]  # img1 predictions (tensor)
results.pandas().xyxy[0]  # img1 predictions (pandas)
# Out:
# Using cache found in /home/user/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2024-2-26 Python-3.8.10 torch-1.13.1 CUDA:0 (AMD Radeon RX 580 2048SP, 16384MiB)
#
# Fusing layers...
# YOLOv5n summary: 213 layers, 1867405 parameters, 0 gradients
# Adding AutoShape...
# image 1/1: 720x1280 3 persons, 1 tie
# Speed: 1847.5ms pre-process, 25.4ms inference, 88.3ms NMS per image at shape (1, 3, 384, 640)
# <PIL.Image.Image image mode=RGB size=1280x720>
#          xmin        ymin         xmax        ymax  confidence  class    name
# 0  138.020142  214.475311   734.600342  720.000000    0.717565      0  person
# 1  713.094727   70.122986  1198.428833  720.000000    0.508350      0  person
# 2    0.000000  447.509216   158.421570  648.486023    0.345959      0  person
# 3  444.834167  329.137268   678.243103  720.000000    0.311246     27     tie

# %%
import cv2

# download video file with torch.hub
video_path = 'car_chase_01.mp4'
torch.hub.download_url_to_file('https://github.com/dannylee1020/object-detection-video/raw/master/videos/car_chase_01.mp4', video_path)
cap = cv2.VideoCapture(video_path)

while(cap.isOpened()):
    ret, frame = cap.read()
    if ret:
        results = model(ret)
        results.print()
        cv2.imshow("frame", results.xyxy[0])
        cv2.waitKey(1)
    else:
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Using cache found in /home/user/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2024-2-26 Python-3.8.10 torch-1.13.1 CUDA:0 (AMD Radeon RX 580 2048SP, 16384MiB)
#
# Fusing layers...
# YOLOv5n summary: 213 layers, 1867405 parameters, 0 gradients
# Adding AutoShape...
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# <ipython-input-3-0a45fc475e57> in <module>
#       8
#       9 # Inference
# ---> 10 results = model(imgs)
#      11
#      12 # Results
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.8/dist-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      25         def decorate_context(*args, **kwargs):
#      26             with self.clone():
# ---> 27                 return func(*args, **kwargs)
#      28         return cast(F, decorate_context)
#      29
#
# ~/.cache/torch/hub/ultralytics_yolov5_master/models/common.py in forward(self, ims, size, augment, profile)
#     800                 f = f"image{i}"  # filename
#     801                 if isinstance(im, (str, Path)):  # filename or uri
# --> 802                     im, f = Image.open(requests.get(im, stream=True).raw if str(im).startswith("http") else im), im
#     803                     im = np.asarray(exif_transpose(im))
#     804                 elif isinstance(im, Image.Image):  # PIL Image
#
# /usr/local/lib/python3.8/dist-packages/PIL/Image.py in open(fp, mode, formats)
#    3281         warnings.warn(message)
#    3282     msg = "cannot identify image file %r" % (filename if filename else fp)
# -> 3283     raise UnidentifiedImageError(msg)
#    3284
#    3285
#
# UnidentifiedImageError: cannot identify image file <_io.BytesIO object at 0x7f4080ffa0e0>
